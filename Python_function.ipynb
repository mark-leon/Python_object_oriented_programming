# %%
def getFraction(dividend,divisor):
    try:
        a = (dividend/divisor)%1
        print(a)
    except Exception:
        print(0)
getFraction(5,4)




def AmiKenoMota(height,weight):
    h = (height/100)
    bmi = round(weight/(h*h),1)
    if bmi<18.5:
        print("Score is "+str(bmi) +".You are underweight")
    elif (bmi >= 18.5 and bmi<24.9):
        print("Score is "+str(bmi) +".You are normal")
    elif (bmi >= 25 and bmi<=30):
        print("Score is "+str(bmi) +".You are overweight")
    else:
        print("Score is "+str(bmi) +".You are obese")
AmiKenoMota(175,96)



def DivisorAdder(min,max,divisor):
    count = 0
    for x in range(min, max):
        if x% divisor == 0:
            count = count+x
    print(count)
DivisorAdder(3,16,3)




def FoodPanda(meal, location ='Mohakhali'):
    thisdict = {
      "BBQ Chicken Cheese Burger": 250,
      "Beef Burger": 170,
      "Naga Drums": 200, 
      }
    for x in thisdict.keys():
        if (x == meal and location =='Mohakhali'):
            print(thisdict[x]+ 40+thisdict[x] *0.08)
            break
        elif x== meal:
            print(thisdict[x]+ 60+thisdict[x] *0.08)
            break
FoodPanda('Beef Burger', 'Dhanmondi')
FoodPanda('Beef Burger')




def replace_domain(a,b,c='kaaj.com'):
    d= a[a.index('@')+1:]
    e = a[:a.index('@')+1]
    if(d=='kaaj.com'):
        print("Changed: "+e+b)
    else:
        print("Unchanged: "+a)       
replace_domain('alice@kaaj.com', 'sheba.xyz', 'kaaj.com')
replace_domain('bob@sheba.xyz', 'sheba.xyz')




def VowelChecker(Fullname):
    vowelCount = 0
    a = []
    for x in Fullname:
        if(x=='A' or x == 'a' or x =='E' or x == 'e' or x =='I' or x =='i' or x=='O' or x=='o' or x=='U' or x=='u'):
            vowelCount = vowelCount+1
            a.append(x)
    if vowelCount == 0:
        print("No vowels in the name")
    else:
        print("Vowels:"  + ', '.join(a)+".Total number of vowels:"+str(vowelCount))
        
Fullname = input("Enter your Fullname: ")
VowelChecker(Fullname)





def Palindrome(st):
    str = ''

    for i in st:
        if i == ' ':
            continue
        str = str + i
    for i in range(0, int(len(str)/2)):
        if str[i] != str[len(str)-i-1]:
            return False
    return True

s = "nurses run"
x = Palindrome(s)
if (x):
    print("Palindrome")
else:
    print("Not a Palindrome")




def TimeCount(Totaldays):
    years = int(Totaldays/365)
    months = int((Totaldays%365)/30)
    days = (Totaldays%365)%30
    print(str(years)+" years,"+str(months)+" months,and "+str(days)+"days")
TimeCount(4000)





def Kindergarden(s):
    a = len(s)
    b =[0]
    
    for x in range(a):
        if x!= a-1 and (s[x] =='.' or s[x] =='?' or s[x] =='?'):
            b.append(x+2)
        
    str =''
    for y in range(a):
        if y in b:
            str= str+s[y].upper()
        else:
            str = str+s[y]
    print(str)
Kindergarden("my favourite animal is a dog. a dog has sharp teeth so that it can eat flesh very easily. do you know my pet dog’s name? i love my pet very much.")
# Out:
# 0.25
# Score is 31.3.You are obese
# 45
# 243.6
# 223.6
# Changed: alice@sheba.xyz
# Unchanged: bob@sheba.xyz
# Enter your Fullname: Leon
# Vowels:e, o.Total number of vowels:2
# Palindrome
# 10 years,11 months,and 20days
# My favourite animal is a dog. A dog has sharp teeth so that it can eat flesh very easily. Do you know my pet dog’s name? I love my pet very much.
