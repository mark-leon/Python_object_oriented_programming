# %%
class royal:
  name='elizabeth'
  @classmethod
  def intro(cls,msg):
    print('Welcome your majesty', name)
royal.name='victoria'
royal.intro('Welcome to British Royal family', name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-45cbf2239053> in <module>()
#       5     print('Welcome your majesty', name)
#       6 royal.name='victoria'
# ----> 7 royal.intro('Welcome to British Royal family', name)
#
# NameError: name 'name' is not defined
