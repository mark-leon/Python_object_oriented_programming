# %%
# class cuisine:
#   def __init__(self, food1= 'pizza'): 
#     self.food1=food1
# class italian(cuisine):
#    def __init__(self, food2 = 'pasta'): 
#      super().__init_() 
#      self.food2 = food2
# def main():
#   obj = italian()
#   print(obj.food1, obj.food2)
# main ()



class animal:
  def pet (self): 
    return self.wild()
  def wild(self):
    return 'tiger'
class arthropods (animal):
  def wild(self):
    return 'butterfly'
obj1=animal()
obj2=arthropods()
print(obj1.wild(),obj2.wild())
# Out:
# tiger butterfly
